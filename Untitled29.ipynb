# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
ADS=pd.read_csv('avocado.csv')
ADS
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1              1  20-12-2015          1.35      54876.98    674.28   44638.81
# 2              2  13-12-2015          0.93     118220.22    794.70  109149.67
# 3              3  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4              4  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512          10  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
ADS['Date']= pd.to_datetime(ADS['Date'])

# %%
ADS['Date']
# Out:
# 0      2015-12-27
# 1      2015-12-20
# 2      2015-12-13
# 3      2015-06-12
# 4      2015-11-29
#           ...
# 1512   2016-10-16
# 1513   2016-09-10
# 1514   2016-02-10
# 1515   2016-09-25
# 1516   2016-09-18
# Name: Date, Length: 1517, dtype: datetime64[ns]

# %%
ADS['Date']=pd.to_datetime(ADS['Date'],format='%Y-%m-%d')
ADS['year']= ADS['Date'].dt.year
ADS['month']= ADS['Date'].dt.month
ADS['day']= ADS['Date'].dt.day

# %%
ADS1=ADS.drop('Date',axis=1)

# %%
ADS1=pd.concat([ADS['Date'],ADS1],axis=1)

# %%
ADS1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   datetime64[ns]
#  1   Unnamed: 0    1517 non-null   int64
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   int64
#  13  region        1517 non-null   object
#  14  month         1517 non-null   int64
#  15  day           1517 non-null   int64
# dtypes: datetime64[ns](1), float64(9), int64(4), object(2)
# ...

# %%
ADS.dropna(inplace=True)

# %%
ADS1
# Out:
#            Date  Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# 0    2015-12-27           0          1.33      64236.62   1036.74   54454.85
# 1    2015-12-20           1          1.35      54876.98    674.28   44638.81
# 2    2015-12-13           2          0.93     118220.22    794.70  109149.67
# 3    2015-06-12           3          1.08      78992.15   1132.00   71976.41
# 4    2015-11-29           4          1.28      51039.60    941.48   43838.39
# ...         ...         ...           ...           ...       ...        ...
# 1512 2016-10-16          10          1.39     190846.01  57529.11   56366.66
# 1513 2016-09-10          11          1.51     178235.75  43325.87   52189.61
# 1514 2016-02-10          12          1.48     178410.82  46364.75   52893.38
# 1515 2016-09-25          13          1.47     189131.52  54110.79   53593.58
# 1516 2016-09-18          14          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
ADS.drop('Unnamed: 0',axis=1,inplace=True)
ADS.drop('Date',axis=1,inplace=True)

# %%
ADS = pd.DataFrame(ADS)
ADS.rename(columns = {'4046':'Total number of avocados with PLU 4046 sold', '4225':'Total number of avocados with PLU 4225 sold', 
                              '4770':'Total number of avocados with PLU 4770 sold'}, inplace = True) 
(ADS.columns)
# Out:
# Index(['AveragePrice', 'Total Volume',
#        'Total number of avocados with PLU 4046 sold',
#        'Total number of avocados with PLU 4225 sold',
#        'Total number of avocados with PLU 4770 sold', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'month', 'day'],
#       dtype='object')

# %%
ADS
# Out:
#       AveragePrice  Total Volume  Total number of avocados with PLU 4046 sold  \
# 0             1.33      64236.62                                      1036.74
# 1             1.35      54876.98                                       674.28
# 2             0.93     118220.22                                       794.70
# 3             1.08      78992.15                                      1132.00
# 4             1.28      51039.60                                       941.48
# ...            ...           ...                                          ...
# 1512          1.39     190846.01                                     57529.11
# 1513          1.51     178235.75                                     43325.87
# 1514          1.48     178410.82                                     46364.75
# 1515          1.47     189131.52                                     54110.79
# 1516          1.43     182978.30                                     43116.41
#
# ...

# %%
ADS.shape
# Out:
# (1517, 14)

# %%
ADS.dtypes
# Out:
# AveragePrice                                   float64
# Total Volume                                   float64
# Total number of avocados with PLU 4046 sold    float64
# Total number of avocados with PLU 4225 sold    float64
# Total number of avocados with PLU 4770 sold    float64
# Total Bags                                     float64
# Small Bags                                     float64
# Large Bags                                     float64
# XLarge Bags                                    float64
# type                                            object
# year                                             int64
# region                                          object
# month                                            int64
# day                                              int64
# dtype: object

# %%
ADS.columns
# Out:
# Index(['AveragePrice', 'Total Volume',
#        'Total number of avocados with PLU 4046 sold',
#        'Total number of avocados with PLU 4225 sold',
#        'Total number of avocados with PLU 4770 sold', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'month', 'day'],
#       dtype='object')

# %%
ADS.columns
# Out:
# Index(['AveragePrice', 'Total Volume',
#        'Total number of avocados with PLU 4046 sold',
#        'Total number of avocados with PLU 4225 sold',
#        'Total number of avocados with PLU 4770 sold', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'month', 'day'],
#       dtype='object')

# %%
ADS.describe()
# Out:
#        AveragePrice  Total Volume  \
# count   1517.000000  1.517000e+03
# mean       1.074990  1.601879e+06
# std        0.188891  4.433143e+06
# min        0.490000  3.875074e+04
# 25%        0.980000  1.474700e+05
# 50%        1.080000  4.027919e+05
# 75%        1.190000  9.819751e+05
# max        1.680000  4.465546e+07
#
#        Total number of avocados with PLU 4046 sold  \
# count                                 1.517000e+03
# mean                                  6.464387e+05
# std                                   1.947614e+06
# min                                   4.677200e+02
# 25%                                   2.040034e+04
# 50%                                   8.175117e+04
# 75%                                   3.775785e+05
# max                                   1.893304e+07
#
#        Total number of avocados with PLU 4225 sold  \
# count                                 1.517000e+03
# mean                                  6.114375e+05
# ...

# %%
ADS.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.18, 1.29, 1.25, 1.03, 1.39,
#        1.4 , 1.36, 1.3 , 0.88, 1.21, 0.9 , 0.94, 0.75, 0.77, 0.81, 0.8 ,
#        0.72, 0.79, 0.67, 0.82, 0.68, 0.76, 0.91, 1.38, 0.92, 0.78, 0.74,
#        0.62, 0.83, 0.87, 0.73, 0.7 , 0.89, 0.85, 1.44, 1.42, 1.41, 0.49,
#        0.53, 0.66, 0.56, 0.6 , 0.71, 0.65, 0.58, 0.54, 0.52, 0.51, 0.57,
#        0.63, 0.64, 0.61, 0.84, 0.86, 0.69, 1.52, 1.53, 1.49, 1.48, 1.56,
#        1.62, 1.63, 1.46, 1.51, 1.61, 1.47, 1.66, 1.57, 1.6 , 1.5 , 1.68,
#        1.54, 1.64, 1.58])

# %%
ADS.AveragePrice.value_counts()
# Out:
# 1.08    46
# 0.99    44
# 1.03    44
# 1.09    43
# 1.10    43
#         ..
# 1.61     1
# 1.66     1
# 1.60     1
# 0.64     1
# 1.64     1
# Name: AveragePrice, Length: 113, dtype: int64

# %%
ADS.isnull().sum()
# Out:
# AveragePrice                                   0
# Total Volume                                   0
# Total number of avocados with PLU 4046 sold    0
# Total number of avocados with PLU 4225 sold    0
# Total number of avocados with PLU 4770 sold    0
# Total Bags                                     0
# Small Bags                                     0
# Large Bags                                     0
# XLarge Bags                                    0
# type                                           0
# year                                           0
# region                                         0
# month                                          0
# day                                            0
# dtype: int64

# %%
sns.heatmap(ADS.isnull(),annot=True)

# %%
ADS.keys()
# Out:
# Index(['AveragePrice', 'Total Volume',
#        'Total number of avocados with PLU 4046 sold',
#        'Total number of avocados with PLU 4225 sold',
#        'Total number of avocados with PLU 4770 sold', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'month', 'day'],
#       dtype='object')

# %%
ADS.shape
# Out:
# (1517, 14)

# %%
ADScor=ADS.corr()
ADScor
# Out:
#                                              AveragePrice  Total Volume  \
# AveragePrice                                     1.000000     -0.140470
# Total Volume                                    -0.140470      1.000000
# Total number of avocados with PLU 4046 sold     -0.190096      0.985568
# Total number of avocados with PLU 4225 sold     -0.092084      0.987154
# Total number of avocados with PLU 4770 sold     -0.100567      0.934347
# Total Bags                                      -0.111597      0.967689
# Small Bags                                      -0.097682      0.960642
# Large Bags                                      -0.177480      0.910226
# XLarge Bags                                     -0.048284      0.521717
# year                                             0.178683     -0.004189
# month                                            0.060642     -0.055212
# day                                              0.092589     -0.034857
#
# ...

# %%
sns.heatmap(ADScor)

# %%
sns.color_palette?

# %%
plt.figure(figsize=(10,6))
sns.heatmap(ADScor,cmap='Blues',annot=True)

# %% [markdown]
# Obsevatons
# Dark shades  are highly correlated

# %%
plt.figure(figsize=(10,6))
sns.heatmap(ADScor,cmap='YlOrRd_r',annot=True)

# %%
ADS.columns
# Out:
# Index(['AveragePrice', 'Total Volume',
#        'Total number of avocados with PLU 4046 sold',
#        'Total number of avocados with PLU 4225 sold',
#        'Total number of avocados with PLU 4770 sold', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'month', 'day'],
#       dtype='object')

# %%
ADS['AveragePrice'].plot.box()

# %%
ADS['Total Volume'].plot.box()

# %%
ADS['Total Bags'].plot.box()

# %%
ADS['Small Bags'].plot.box()

# %%
ADS['Large Bags'].plot.box()

# %%
ADS['XLarge Bags'].plot.box()

# %%
sns.distplot(ADS['AveragePrice'])

# %%
collist=ADS.columns.values
ncol=14
nrows=20

# %%
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(ADS[collist[i]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-7e6ac3914f22> in <module>
#       2 for i in range(0,len(collist)):
#       3     plt.subplot(nrows,ncol,i+1)
# ----> 4     sns.distplot(ADS[collist[i]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     177
#     178     # Make a a 1-d float array
# --> 179     a = np.asarray(a, np.float)
#     180     if a.ndim > 1:
#     181         a = a.squeeze()
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
# ...

# %%
sns.distplot(ADS['Total Volume'])

# %%
sns.distplot(ADS['Total Bags'])

# %%
sns.distplot(ADS['Small Bags'])

# %%
sns.distplot(ADS['Large Bags'])

# %%
sns.distplot(ADS['XLarge Bags'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['Total Volume'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['Total Bags'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['Small Bags'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['Large Bags'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['XLarge Bags'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['day'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['year'])

# %%
plt.scatter(ADS['AveragePrice'],ADS['month'])

# %%
sns.pairplot(ADS)

# %%
from scipy.stats import zscore
z=np.abs(zscore(ADS))
z
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-920027ed3de9> in <module>
#       1 from scipy.stats import zscore
# ----> 2 z=np.abs(zscore(ADS))
#       3 z
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in zscore(a, axis, ddof, nan_policy)
#    2414         sstd = np.nanstd(a=a, axis=axis, ddof=ddof, keepdims=True)
#    2415     else:
# -> 2416         mns = a.mean(axis=axis, keepdims=True)
#    2417         sstd = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2418
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
# --> 154                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     155         if is_float16_result and out is None:
# ...

# %%
x=ADS.iloc[:,1:-1]
x
# Out:
#       Total Volume  Total number of avocados with PLU 4046 sold  \
# 0         64236.62                                      1036.74
# 1         54876.98                                       674.28
# 2        118220.22                                       794.70
# 3         78992.15                                      1132.00
# 4         51039.60                                       941.48
# ...            ...                                          ...
# 1512     190846.01                                     57529.11
# 1513     178235.75                                     43325.87
# 1514     178410.82                                     46364.75
# 1515     189131.52                                     54110.79
# 1516     182978.30                                     43116.41
#
#       Total number of avocados with PLU 4225 sold  \
# 0                                        54454.85
# 1                                        44638.81
# ...

# %%
y=ADS.iloc[:,0]
y
# Out:
# 0       1.33
# 1       1.35
# 2       0.93
# 3       1.08
# 4       1.28
#         ...
# 1512    1.39
# 1513    1.51
# 1514    1.48
# 1515    1.47
# 1516    1.43
# Name: AveragePrice, Length: 1517, dtype: float64

# %%
x.shape
# Out:
# (1517, 12)

# %%
y.shape
# Out:
# (1517,)

# %%
y=y.values.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.39,random_state=52)

# %%
x_train.shape
# Out:
# (925, 12)

# %%
y_train.shape
# Out:
# (925, 1)

# %%
x_test.shape
# Out:
# (592, 12)

# %%
y_test.shape
# Out:
# (592, 1)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-dd304f997297> in <module>
# ----> 1 lm.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print('r2 score corresponding to random state: ', r_state,'is: ',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print('max r2 score corresponding to',final_r_state,'is',max_r_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-6af1d709121f> in <module>
#       8     x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
#       9     regr=linear_model.LinearRegression()
# ---> 10     regr.fit(x_train,y_train)
#      11     y_pred=regr.predict(x_test)
#      12     r2_scr=r2_score(y_test,y_pred)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# ...

# %%
#not trained

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-90adca069ead> in <module>
# ----> 1 lg.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1525
#    1526         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1527                          accept_large_sparse=solver != 'liblinear')
#    1528         check_classification_targets(y)
#    1529         self.classes_ = np.unique(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
# ...

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.svm import SVC

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.39,random_state=52)

# %%
mnb=MultinomialNB()

# %%
mnb.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-b8041c8f4fa7> in <module>
# ----> 1 mnb.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     607         self : object
#     608         """
# --> 609         X, y = self._check_X_y(X, y)
#     610         _, n_features = X.shape
#     611         self.n_features_ = n_features
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in _check_X_y(self, X, y)
#     473
#     474     def _check_X_y(self, X, y):
# --> 475         return check_X_y(X, y, accept_sparse='csr')
#     476
#     477     def _update_class_log_prior(self, class_prior=None):
#
# ...

# %%
#error is not solved me please help me out remove error
