# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
BDS=pd.read_csv('baseball.csv')
BDS
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
BDS.shape
# Out:
# (30, 17)

# %%
BDS.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
BDS.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
BDS.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(BDS.isnull())

# %%
BDS.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
BDS['R'].plot.box()

# %%
BDS['AB'].plot.box()

# %%
BDS['H'].plot.box()

# %%
BDS['2B'].plot.box()

# %%
BDS['3B'].plot.box()

# %%
BDS['HR'].plot.box()

# %%
BDS['BB'].plot.box()

# %%
BDS['SO'].plot.box()

# %%
BDS['SB'].plot.box()

# %%
BDS['RA'].plot.box()

# %%
BDS['ER'].plot.box()

# %%
BDS['ERA'].plot.box()

# %%
BDS['CG'].plot.box()

# %%
BDS['SHO'].plot.box()

# %%
BDS['SV'].plot.box()

# %%
BDS['E'].plot.box()

# %%
BDS.plot?

# %%
BDS.plot(kind='box',subplots=True,layout=(1,17))
plt.show()

# %%
collist=BDS.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(BDS[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# to check Distribustion of skewness

# %%
sns.distplot(BDS['W'])

# %%
sns.distplot(BDS['R'])

# %%
plt.figure(figsize=(50,50))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(BDS[collist[i]])

# %%
plt.scatter(BDS['W'],BDS['R'])

# %%
plt.scatter(BDS['W'],BDS['AB'])

# %%
plt.scatter(BDS['W'],BDS['H'])

# %%
sns.pairplot(BDS)

# %%
from scipy.stats import zscore
z=np.abs(zscore(BDS))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threshold=2
print(np.where(z>2))
# Out:
# (array([ 0,  2,  5,  5,  8, 11, 14, 15, 15, 15, 15, 16, 17, 17, 19, 22, 23,
#        25, 27, 29, 29, 29], dtype=int64), array([ 8, 13,  1,  6, 15,  6, 16, 10, 11, 12, 15, 16,  8, 14,  9,  4,  6,
#        14,  9, 10, 11, 12], dtype=int64))

# %%
z[4][8]
# Out:
# 0.10586627681486001

# %%
BDS[2:25]
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# ...

# %%
x=BDS.iloc[:,1:-1]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10  34
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4  48
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10  43
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12  60
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10  40
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9  45
# ...

# %%
x.shape
# Out:
# (30, 15)

# %%
y=BDS.iloc[:,0].values
y
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  81,  80,  78,  88,  86,  85,
#         76,  68, 100,  98,  97,  68,  64,  90,  83,  71,  67,  63,  92,
#         84,  79,  74,  68], dtype=int64)

# %%
y.shape
# Out:
# (30,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-a722ae2f4bb3> in <module>
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (20, 15)

# %%
y_train.shape
# Out:
# (20,)

# %%
x_test.shape
# Out:
# (10, 15)

# %%
y_test.shape
# Out:
# (10,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.score(x_train,y_train)
# Out:
# 0.9779269545686305

# %%
lm.coef_
# Out:
# array([ 8.26178036e-02, -3.02957742e-02,  3.37556602e-02, -9.29438583e-02,
#         1.49126041e-01,  2.81484517e-02, -2.22717193e-02, -1.15708559e-02,
#         5.74472631e-03,  1.71983953e-01, -3.28029011e-02, -3.41027358e+01,
#         7.08032746e-01,  1.34230578e-01,  9.86835453e-01])

# %%
lm.intercept_
# Out:
# 176.44330494113927

# %%
BaseDS=np.array([1000])
BDS=BaseDS.reshape(-1,1)
lm.predict(BDS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-48c218ce9206> in <module>
#       1 BaseDS=np.array([1000])
#       2 BDS=BaseDS.reshape(-1,1)
# ----> 3 lm.predict(BDS)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
# --> 209                                dense_output=True) + self.intercept_
#     210
#     211     def predict(self, X):
#
# ...

# %% [markdown]
# with his predicton (score of 97% ) we predict that if no. of runs is 1000 then the chances of win is 176 times

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print('r2 score corresponding to random state: ', r_state,'is: ',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print('max r2 score corresponding to',final_r_state,'is',max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.7862570694322208
# r2 score corresponding to random state:  43 is:  -0.7822504245858664
# r2 score corresponding to random state:  44 is:  0.8211429708425837
# r2 score corresponding to random state:  45 is:  0.6272171896144039
# r2 score corresponding to random state:  46 is:  0.6589236848611074
# r2 score corresponding to random state:  47 is:  0.9434975046785453
# r2 score corresponding to random state:  48 is:  0.9293594806179837
# r2 score corresponding to random state:  49 is:  0.38208276398577545
# r2 score corresponding to random state:  50 is:  0.7183650712132145
# r2 score corresponding to random state:  51 is:  0.4643624202297607
# r2 score corresponding to random state:  52 is:  0.5257047376834777
# r2 score corresponding to random state:  53 is:  0.2645106825290673
# r2 score corresponding to random state:  54 is:  0.9253875762701788
# r2 score corresponding to random state:  55 is:  0.7870201618796125
# ...

# %%
lm.predict(x_test)
# Out:
# array([79.13991861, 84.5530222 , 77.23907595, 79.0765474 , 93.55902705,
#        84.15453324])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=31,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([93.10956737, 60.84165992, 95.5833945 , 80.71823185, 95.94708112,
#        87.40490314])

# %%
#cross validaion
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
print('r2 score is ',r2_score(y_test,y_pred))
print('MSE is',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is  0.27834217806057215
# MSE is 8.448904439048595
